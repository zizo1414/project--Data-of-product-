# %% [markdown]
# # Data Analyst Professional Practical Exam Submission
#
# **You can use any tool that you want to do your analysis and create visualizations. Use this template to write up your summary for submission.**
#
# You can use any markdown formatting you wish. If you are not familiar with Markdown, read the [Markdown Guide](https://s3.amazonaws.com/talent-assets.datacamp.com/Markdown+Guide.pdf) before you start.

# %% [markdown]
# ## 📝 Task List
#
# Your written report should include written text summaries and graphics of the following:
# - Data validation:
#   - Describe validation and cleaning steps for every column in the data
# - Exploratory Analysis:
#   - Include two different graphics showing single variables only to demonstrate the characteristics of data
#   - Include at least one graphic showing two or more variables to represent the relationship between features
#   - Describe your findings
# - Definition of a metric for the business to monitor
#   - How should the business use the metric to monitor the business problem
#   - Can you estimate initial value(s) for the metric based on the current data
# - Final summary including recommendations that the business should undertake
#
# *Start writing report here..*
# first i started with process of data validation including accuracy , Completeness,Consistency,Validity,integrity,Reliability,
# data quality,governance
# Data validation is a process or set of rules and procedures used to ensure that data entered into a system is accurate, complete, and consistent. The primary purpose of data validation is to prevent errors, inconsistencies, and inaccuracies in data that can lead to problems in business processes, reporting, and decision-making. Here are some key aspects and meanings of data validation:
#
#
# *week*: Week sale was made, counted as weeks since product launch.
#    - Data Type: Integer
#    - Data Validation: i  Ensured that the values are non-negative integers and within a reasonable range based on the product launch date.
#    - *sales_method*: Character, which of the three sales methods were used for that customer.
#    - Data Type: object.
#    - Data Validation: i Ensured that the values correspond to the expected sales methods and handle any potential misspellings or inconsistencies.
#    - . *customer_id*: Unique identifier for the customer.
#    - Data Type: String (Text).
#    - Data Validation: i Ensured that customer IDs are unique, and there are no duplicates. we can also validate the format or length of customer IDs if necessary
#    -
#    - 4. *nb_sold*: Number of new products sold.
#    - Data Type: Integer.
#    - Data Validation: i Ensured that the values are non-negative and within a reasonable range.
#
#
# 5. *revenue*: Numeric revenue from the sales, rounded to 2 decimal places.
#    - Data Type: Float (for precision with two decimal places).
#    - Data Validation:  i Ensured that the values are non-negative and rounded to two decimal places.
#
# 6. *years_as_customer*: Number of years the customer has been buying from us (company founded in 1984).
#    - Data Type:  Integer.
#    - Data Validation: i Ensured that the values are non-negative and realistic in the context of your business (e.g., not too large or too small).
#
#
#
# 7. *nb_site_visits*: Number of times the customer has visited our website in the last 6 months.
#    - Data Type: Integer.
#    - Data Validation:  i Ensured that the values are non-negative integers and within a reasonable range. You can also consider setting a maximum value based on the expected behavior.
#
#
#
# 8. *state*: Location of the customer, i.e., where orders are shipped.
#    - Data Type:  object.
#    - Data Validation: i Ensured that the values correspond to valid states or locations in your business context. Handle potential misspellings or inconsistencies.
#
# its important to mention that  data types and validation should align with the goals of my analysis and the characteristics of my dataset. It's important to strike a balance between being stringent enough to catch errors and flexible enough to accommodate variations in the data.
#
# first i started with adjusting and  fixing  the objects of sales_method
# and then i suggested that we willnot  drop nulls which will affect our data  so we replaced the nulls with average of each sales_method and i kept the object and float columns as they are as there is no need to adjust them  and i checked that there are no duplicates in the data for more accurate results
#
#
# first question ? how many customers were there for each method
# the matrix and pivot table shows that email method is the most used method
#
# sales_method
# Call            4962
# Email           7466
# Email + Call    2572
#
# second question ?What does the spread of the revenue look like overall? And for each method
# the matrix and graphs show that the email method is the most method has brought revenue
# and the most used method
#
# sales_method
# Call            236179.09
# Email           725156.55
# Email + Call    472350.54
#
# through our graphs and matrix table it shows that email is the most sales method that brought revenue for the company as it the most method that made transactions and the most used method
#
#  sales method     average revenue
# Call             47.597559
# Email            97.127853
# Email + Call    183.651065
#
# eamil+call has a higher average but not highest revenue  and that aslo shown by our graphs and matrix table
#
# Was there any difference in revenue over time for each of the methods?
#
# through our graph and matrix tables show that in the first week has the highest revenue and most product sold number
#
# but in terms of average we can  see that the sixth week has the highest average
#
#
# week nb_sold  	revenue
#
# 1	3721	295146.48
# 2	2491	215400.84
# 3	2411	200078.75
# 4	2575	257272.51
# 5	2574	282675.43
# 6	1228	183112.17
#
# week   average revenue over weeks
# 1     79.319129
# 2     86.471634
# 3     82.985794
# 4     99.911654
# 5    109.819514
# 6    149.114145
#
#
#
# so based on the data i would suggest the sales team to rely on email which is the most method has brought revenue and also cost time saving factor is great  for the employees
#
# based on th data we found that most of our product shipped to the following states so these are states that requested our products (sample of states)all of them below
#
# states            nb_sold
# California        1872
# Texas             1187
# New York           965
# Florida            904
# Illinois           617
# Pennsylvania       598
# Ohio               566
# Michigan           498
# Georgia            489
#
# based on the data we found that the majority of our customers who have been buying from us are from 15 years   number of years customer has been buying from us so we considered them new customers
# and that supported by grapgh and matrix
# based on the data most of customers who bought our  products are visiting our website regularly over the past six month
# and that supported by our graphs and matrix
#
# this matrix shows the number of product sales and total revenue over weeks sales
# it shows that in the first week we were selling more products so the first week has higher revenue but in terms of average the last week has the highest average that supported through our graphs and matrix
#
#
#
# 	nb_sold	revenue
# week
# 1	3721	295146.48
# 2	2491	215400.84
# 3	2411	200078.75
# 4	2575	257272.51
# 5	2574	282675.43
# 6	1228	183112.17
#
# week   average revenue over weeks
# 1     79.319129
# 2     86.471634
# 3     82.985794
# 4     99.911654
# 5    109.819514
# 6    149.114145
#
#  Definition of a metric for the business to monitor
#  ○ How should the business monitor what they want to achieve?
#  ○ Estimate the initial value(s) for the metric based on the current data?
#
#  the metric we are going to rely on is total revenue and average  of mail method which is the most method has brought revenue we should  track it to know what we have achieved and how the revenue would go in the future .
#
#
#   another metric is the average of site visits from our purchased customer
#  we can also track the number of customers's website visits  customers who visited  our website frequently  over the past 6 months a  way to do this is to compare the average number of visits per customer over time
#
#  another mertric we found in our data that customer segmentation that most of our customer are new customers from 15  years  number of years customer has been buying from us so we can also track that by time to know if the customers will continue buying from us or not
#
#  inital value
#  1-  Email           725156.55  total revenue of mail method
#  2- Email            97.127853  average of revenue mail method
#
#  24.9 is the average of number website visits so can also track that to  know the direction of our business this actually a good number that the purchased customers who visit our website are visting us regularly to check our products and for engagement .
#
#
#  4.99 is the average of number of years customers have been buying from us which means the most of our customer are new customers so we can also track the number of years customer have been buying from us which is a positive and negative  sign that most of our customer
#  are new customers but also we need to keep the the loyal customers and win them back retain them  and its  important to have strategies in place to cultivate customer loyalty and encourage repeat purchases. This could include offering incentives such as loyalty programs, discounts, or personalized promotions, as well as providing excellent customer service, responding to feedback, and building relationships with your customers.
#
#  ● Final summary including recommendations that the business should undertake
#
# i highly recommend the sales team to rely on email method which provides more time and effort and track these three metrics and their inital values to know the direction of the business average of total revenue through mail method and number of site visits
# and also average of number of years customer has been buying from us metric
#
# its important to have strategies in place to cultivate customer loyalty and encourage repeat purchases. This could include offering incentives such as loyalty programs, discounts, or personalized promotions, as well as providing excellent customer service, responding to feedback, and building relationships with your customers.
#
# and regarding site visits metric my recommendation
# One way to do this is to compare the average number of visits per customer over time, and look for changes or trends that may indicate changes in customer behavior or satisfaction. For example, if the average number of visits per customer starts to decline over time, it may be a sign that customers are becoming less engaged with your website or your products.

# %% [markdown]
# ## ✅ When you have finished...
# -  Publish your Workspace using the option on the left
# -  Check the published version of your report:
# 	-  Can you see everything you want us to grade?
#     -  Are all the graphics visible?
# -  Review the grading rubric. Have you included everything that will be graded?
# -  Head back to the [Certification Dashboard](https://app.datacamp.com/certification) to submit your practical exam report and record your presentation

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import numpy as np

# %%
df=pd.read_csv("product_sales.csv")

# %% [markdown]
# i checked the data types of each column
# which the first step of data validation process for each column

# %%
df.dtypes
# Out:
# week                   int64
# sales_method          object
# customer_id           object
# nb_sold                int64
# revenue              float64
# years_as_customer      int64
# nb_site_visits         int64
# state                 object
# dtype: object

# %% [markdown]
# i check the shape

# %%
df.shape
# Out:
# (15000, 8)

# %% [markdown]
# info about the coulmns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   week               15000 non-null  int64
#  1   sales_method       15000 non-null  object
#  2   customer_id        15000 non-null  object
#  3   nb_sold            15000 non-null  int64
#  4   revenue            13926 non-null  float64
#  5   years_as_customer  15000 non-null  int64
#  6   nb_site_visits     15000 non-null  int64
#  7   state              15000 non-null  object
# dtypes: float64(1), int64(4), object(3)
# memory usage: 937.6+ KB

# %% [markdown]
# i check the nulls of all columns

# %%
df.isnull().sum()
# Out:
# week                    0
# sales_method            0
# customer_id             0
# nb_sold                 0
# revenue              1074
# years_as_customer       0
# nb_site_visits          0
# state                   0
# dtype: int64

# %% [markdown]
# seond step to check the duplicates at level of all rows

# %%
df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [week, sales_method, customer_id, nb_sold, revenue, years_as_customer, nb_site_visits, state, Customer_segments]
# Index: []

# %% [markdown]
# first i check the week sales column
# *week*: Week sale was made, counted as weeks since product launch.
#    - Data Type: Integer
#    - Data Validation: i  Ensured that the values are non-negative integers and within a reasonable range based on the product launch

# %%
df.dtypes
# Out:
# week                   int64
# sales_method          object
# customer_id           object
# nb_sold                int64
# revenue              float64
# years_as_customer      int64
# nb_site_visits         int64
# state                 object
# dtype: object

# %%
df.loc[df['week']<=0]
# Out:
# Empty DataFrame
# Columns: [week, sales_method, customer_id, nb_sold, revenue, years_as_customer, nb_site_visits, state, Customer_segments]
# Index: []

# %%
df['week'].value_counts()
# Out:
# 1    3721
# 4    2575
# 5    2574
# 2    2491
# 3    2411
# 6    1228
# Name: week, dtype: int64

# %% [markdown]
# - *sales_method*: Character, which of the three sales methods were used for that customer.
#    - Data Type: object.
#    - Data Validation: i Ensured that the values correspond to the expected sales methods and handle any potential misspellings or inconsistencies.

# %%
df.dtypes
# Out:
# week                    int64
# sales_method           object
# customer_id            object
# nb_sold                 int64
# revenue               float64
# years_as_customer       int64
# nb_site_visits          int64
# state                  object
# Customer_segments    category
# dtype: object

# %%
df['sales_method'].value_counts()
# Out:
# Email           7456
# Call            4962
# Email + Call    2549
# em + call         23
# email             10
# Name: sales_method, dtype: int64

# %% [markdown]
# i fixed the misspellings and errors

# %%
df['sales_method']=df['sales_method'].replace('email','Email')

# %%
df['sales_method']=df['sales_method'].replace('em + call','Email + Call')

# %%
df['sales_method'].unique()
# Out:
# array(['Email', 'Email + Call', 'Call'], dtype=object)

# %%
df['sales_method'].nunique()
# Out:
# 3

# %% [markdown]
#  . *customer_id*: Unique identifier for the customer.
#    - Data Type: String (Text).
#    - Data Validation: i Ensured that customer IDs are unique, and there are no duplicates. we can also validate the format or length of customer IDs if necessary

# %%
df.dtypes
# Out:
# week                    int64
# sales_method           object
# customer_id            object
# nb_sold                 int64
# revenue               float64
# years_as_customer       int64
# nb_site_visits          int64
# state                  object
# Customer_segments    category
# dtype: object

# %%
df['customer_id'].duplicated().sum()
# Out:
# 0

# %%
df['customer_id'].nunique()
# Out:
# 15000

# %%
df['customer_id']
# Out:
# 0        2e72d641-95ac-497b-bbf8-4861764a7097
# 1        3998a98d-70f5-44f7-942e-789bb8ad2fe7
# 2        d1de9884-8059-4065-b10f-86eef57e4a44
# 3        78aa75a4-ffeb-4817-b1d0-2f030783c5d7
# 4        10e6d446-10a5-42e5-8210-1b5438f70922
#                          ...
# 14995    17267b41-d048-4346-8b90-7f787690a836
# 14996    09e10d6f-4508-4b27-895e-4db11ce8302b
# 14997    839653cb-68c9-48cb-a097-0a5a3b2b298b
# 14998    e4dad70a-b23b-407c-8bd3-e32ea00fae17
# 14999    4e077235-7c17-4054-9997-7a890336a214
# Name: customer_id, Length: 15000, dtype: object

# %% [markdown]
#  4. *nb_sold*: Number of new products sold.
#    - Data Type: Integer.
#    - Data Validation: i Ensured that the values are non-negative and within a reasonable range.

# %%
df.dtypes
# Out:
# week                    int64
# sales_method           object
# customer_id            object
# nb_sold                 int64
# revenue               float64
# years_as_customer       int64
# nb_site_visits          int64
# state                  object
# Customer_segments    category
# dtype: object

# %%
df[df['nb_sold']<=0]
# Out:
# Empty DataFrame
# Columns: [week, sales_method, customer_id, nb_sold, revenue, years_as_customer, nb_site_visits, state]
# Index: []

# %%
df['nb_sold'].value_counts()
# Out:
# 10    3677
# 9     3535
# 11    2439
# 8     1941
# 12    1088
# 13     939
# 7      698
# 15     555
# 14      97
# 16      31
# Name: nb_sold, dtype: int64

# %% [markdown]
# 5. *revenue*: Numeric revenue from the sales, rounded to 2 decimal places.
#    - Data Type: Float (for precision with two decimal places).
#    - Data Validation:  i Ensured that the values are non-negative and rounded to two decimal places.
#   i replaced the nulls with a average of each sales_method for a better results instead of dropping the nulls
#   handling missing values by replacing them with average of each method

# %%
df.dtypes
# Out:
# week                    int64
# sales_method           object
# customer_id            object
# nb_sold                 int64
# revenue               float64
# years_as_customer       int64
# nb_site_visits          int64
# state                  object
# Customer_segments    category
# dtype: object

# %%
df['revenue'].isnull().sum()
# Out:
# 1074

# %%
df['revenue'].value_counts()
# Out:
# 51.86     11
# 52.51     10
# 53.25     10
# 52.68      9
# 51.71      9
#           ..
# 187.37     1
# 86.37      1
# 125.97     1
# 182.53     1
# 64.90      1
# Name: revenue, Length: 6743, dtype: int64

# %%
avg_call = round(df[df['sales_method'] == 'Call'  ]['revenue'].mean(),2)
avg_Email = round(df[df['sales_method'] == 'Email'  ]['revenue'].mean(),2)
avg_Email_call = round(df[df['sales_method'] == 'Email + Call'  ]['revenue'].mean(),2)
df.loc[df['sales_method']=='Call', 'revenue'] = df.loc[df['sales_method']=='Call', 'revenue'].fillna(avg_call)
df.loc[df['sales_method']=='Email', 'revenue'] = df.loc[df['sales_method']=='Email', 'revenue'].fillna(avg_Email)
df.loc[df['sales_method']=='Email + Call', 'revenue'] = df.loc[df['sales_method']=='Email + Call', 'revenue'].fillna(avg_Email_call)

# %%
df['revenue'].isnull().sum()
# Out:
# 0

# %% [markdown]
#  *years_as_customer*: Number of years the customer has been buying from us (company founded in 1984).
#    - Data Type:  Integer.
#    - Data Validation: i Ensured that the values are non-negative and realistic in the context of your business (e.g., not too large or too small).

# %%
df['years_as_customer'].dtype
# Out:
# dtype('int64')

# %%
df['years_as_customer'].value_counts()
# Out:
# 1     2504
# 2     1987
# 3     1619
# 0     1471
# 4     1338
# 5     1118
# 6      918
# 7      709
# 8      608
# 9      509
# 10     405
# 11     318
# 12     284
# 13     239
# 14     167
# 15     150
# 16     123
# 17      88
# 18      82
# 19      58
# 20      54
# 22      43
# 21      37
# 24      27
# 26      22
# 23      21
# 25      19
# 27      15
# 30       9
# 33       8
# 34       8
# 28       8
# 31       6
# 32       5
# 29       5
# 35       5
# 36       4
# 39       3
# 38       2
# 37       2
# 63       1
# 47       1
# Name: years_as_customer, dtype: int64

# %%
df.loc[df['years_as_customer']<0]
# Out:
# Empty DataFrame
# Columns: [week, sales_method, customer_id, nb_sold, revenue, years_as_customer, nb_site_visits, state, Customer_segments]
# Index: []

# %% [markdown]
#  *nb_site_visits*: Number of times the customer has visited our website in the last 6 months.
#    - Data Type: Integer.
#    - Data Validation:  i Ensured that the values are non-negative integers and within a reasonable range. we can also consider setting a maximum value based on the expected behavior.

# %%
df.dtypes
# Out:
# week                    int64
# sales_method           object
# customer_id            object
# nb_sold                 int64
# revenue               float64
# years_as_customer       int64
# nb_site_visits          int64
# state                  object
# Customer_segments    category
# dtype: object

# %%
df['nb_site_visits'].value_counts()
# Out:
# 25    1688
# 26    1645
# 24    1601
# 23    1478
# 27    1440
# 22    1200
# 28    1175
# 21     908
# 29     893
# 30     654
# 20     600
# 19     426
# 31     371
# 32     250
# 18     217
# 33     114
# 17     113
# 16      80
# 34      51
# 35      33
# 15      31
# 36      14
# 14       7
# 37       5
# 13       4
# 12       1
# 41       1
# Name: nb_site_visits, dtype: int64

# %%
df['nb_site_visits'].unique()
# Out:
# array([24, 28, 26, 25, 22, 31, 23, 30, 21, 27, 32, 29, 20, 18, 19, 35, 16,
#        17, 33, 36, 34, 15, 37, 14, 13, 12, 41])

# %%
df.loc[df['nb_site_visits']<=0]
# Out:
# Empty DataFrame
# Columns: [week, sales_method, customer_id, nb_sold, revenue, years_as_customer, nb_site_visits, state, Customer_segments]
# Index: []

# %% [markdown]
# *state*: Location of the customer, i.e., where orders are shipped.
#    - Data Type:  object.
#    - Data Validation: i Ensured that the values correspond to valid states or locations in your business context. Handle potential misspellings or inconsistencies.

# %%
df.dtypes
# Out:
# week                    int64
# sales_method           object
# customer_id            object
# nb_sold                 int64
# revenue               float64
# years_as_customer       int64
# nb_site_visits          int64
# state                  object
# Customer_segments    category
# dtype: object

# %%
df['state'].unique()
# Out:
# array(['Arizona', 'Kansas', 'Wisconsin', 'Indiana', 'Illinois',
#        'Mississippi', 'Georgia', 'Oklahoma', 'Massachusetts', 'Missouri',
#        'Texas', 'New York', 'Maryland', 'California', 'Tennessee',
#        'Pennsylvania', 'North Dakota', 'Florida', 'Michigan',
#        'North Carolina', 'Hawaii', 'Colorado', 'Louisiana', 'Virginia',
#        'New Mexico', 'Arkansas', 'Alaska', 'Oregon', 'New Hampshire',
#        'Ohio', 'New Jersey', 'Connecticut', 'Iowa', 'Montana',
#        'Washington', 'Kentucky', 'Alabama', 'Nebraska', 'South Carolina',
#        'Minnesota', 'South Dakota', 'Delaware', 'Maine', 'Utah',
#        'West Virginia', 'Vermont', 'Rhode Island', 'Nevada', 'Idaho',
#        'Wyoming'], dtype=object)

# %%
df['state'].value_counts()
# Out:
# California        1872
# Texas             1187
# New York           965
# Florida            904
# Illinois           617
# Pennsylvania       598
# Ohio               566
# Michigan           498
# Georgia            489
# North Carolina     459
# New Jersey         434
# Virginia           372
# Indiana            354
# Tennessee          340
# Washington         335
# Arizona            321
# Missouri           311
# Massachusetts      294
# Maryland           263
# Wisconsin          253
# Minnesota          245
# Colorado           230
# Louisiana          230
# Oregon             229
# South Carolina     224
# Alabama            214
# Kentucky           213
# Oklahoma           196
# Connecticut        179
# Iowa               165
# Kansas             142
# Mississippi        139
# Arkansas           132
# Utah               124
# Nevada             102
# Nebraska            91
# West Virginia       85
# New Mexico          84
# Hawaii              72
# Maine               63
# ...

# %%
df.isnull().sum()
# Out:
# week                 0
# sales_method         0
# customer_id          0
# nb_sold              0
# revenue              0
# years_as_customer    0
# nb_site_visits       0
# state                0
# dtype: int64

# %% [markdown]
# # visualization shows the distrbution of shipped orders to states

# %%
plt.figure(figsize=(18,10))
plt.hist(df['state'])
plt.xticks(rotation=90)
plt.show()

# %%
df['nb_site_visits'].plot(kind = 'hist')
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
df['nb_site_visits'].mean()
# Out:
# 24.990866666666665

# %% [markdown]
# # new customers segmentations based on years_as customers

# %%
bins = pd.cut(df["years_as_customer"], 4, labels=[  'New_customer' ,"middle", "loyal", "very loyal"])

print(bins)
# Out:
# 0        New_customer
# 1        New_customer
# 2        New_customer
# 3        New_customer
# 4        New_customer
#              ...
# 14995    New_customer
# 14996    New_customer
# 14997    New_customer
# 14998    New_customer
# 14999    New_customer
# Name: years_as_customer, Length: 15000, dtype: category
# Categories (4, object): ['New_customer' < 'middle' < 'loyal' < 'very loyal']

# %%
df['Customer_segments'] = bins

# %%
df[df['Customer_segments']=='New_customer']['revenue'].sum()
# Out:
# 1374824.1199999999

# %%
df['Customer_segments'].value_counts()
# Out:
# New_customer    14344
# middle            617
# loyal              38
# very loyal          1
# Name: Customer_segments, dtype: int64

# %%
df['years_as_customer'].unique()
# Out:
# array([ 0,  1,  6,  3, 10,  9,  7,  4,  2, 20,  8,  5, 17, 36, 15, 14, 19,
#        13, 12, 11, 30, 24, 22, 18, 26, 23, 32, 16, 39, 25, 33, 21, 31, 27,
#        34, 28, 29, 35, 38, 37, 63, 47])

# %% [markdown]
# # visualization shows the number of years customer has been buying from us for example the first 200 rows --
# --single varaible  line  plot

# %%
df['years_as_customer'].head(200).plot()
# Out:
# <AxesSubplot: >

# %%
df.loc[df['Customer_segments']=='New_customer']['years_as_customer'].unique()
# Out:
# array([ 0,  1,  6,  3, 10,  9,  7,  4,  2,  8,  5, 15, 14, 13, 12, 11])

# %%
df.loc[df['Customer_segments']=='middle']['years_as_customer'].unique()
# Out:
# array([20, 17, 19, 30, 24, 22, 18, 26, 23, 16, 25, 21, 31, 27, 28, 29])

# %%
df.loc[df['Customer_segments']=='loyal']['years_as_customer'].unique()
# Out:
# array([36, 32, 39, 33, 34, 35, 38, 37, 47])

# %% [markdown]
# # this visualization shows that most of customers are the ones who buying from us in 15 years since the foundation of the company--- single variable plot

# %%
plt.hist(df['Customer_segments'])
# Out:
# (array([1.4344e+04, 0.0000e+00, 0.0000e+00, 6.1700e+02, 0.0000e+00,
#         0.0000e+00, 3.8000e+01, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([0. , 0.3, 0.6, 0.9, 1.2, 1.5, 1.8, 2.1, 2.4, 2.7, 3. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #how many customers were there for each approach

# %%
df.groupby(['sales_method'])['customer_id'].count()
# Out:
# sales_method
# Call            4962
# Email           7466
# Email + Call    2572
# Name: customer_id, dtype: int64

# %% [markdown]
# # total revenue for each method

# %%
df.groupby('sales_method')['revenue'].sum()
# Out:
# sales_method
# Call            236179.09
# Email           725156.55
# Email + Call    472350.54
# Name: revenue, dtype: float64

# %% [markdown]
# # total  average revenue for each method

# %%
df.groupby('sales_method')['revenue'].mean()
# Out:
# sales_method
# Call             47.597559
# Email            97.127853
# Email + Call    183.651065
# Name: revenue, dtype: float64

# %% [markdown]
# number of  product sold for each method

# %%
df.groupby('sales_method')['nb_sold'].count()
# Out:
# sales_method
# Call            4962
# Email           7466
# Email + Call    2572
# Name: nb_sold, dtype: int64

# %% [markdown]
# #single variable plot shows the count of each sales_method
# # which shows that mail method is the most used method

# %%
plt.hist(df['sales_method'])
# Out:
# (array([7466.,    0.,    0.,    0.,    0., 2572.,    0.,    0.,    0.,
#         4962.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # spread of average revenue for each method two variable plot
# # that shows that email+call has a higher average than mail despite mail is the most method brought revenue

# %%
sns.barplot(x=df['sales_method'],y=df['revenue'])

# %%
 x =  df.groupby('sales_method')['revenue'].sum().index

# %%
y =  df.groupby('sales_method')['revenue'].sum().values

# %% [markdown]
# # spread of total revenue for each method   two varaible plot
# #What does the spread of the revenue look like overall? And for each method?

# %%
sns.barplot(x=x , y= y)
plt.title('distrbution of revenues')
plt.xlabel('eachmethod')
plt.ylabel('revenues')
plt.show()

# %% [markdown]
# # two variable plot shows the average of total revenue of each sales method
# #What does the spread of the revenue look like overall? And for each method?

# %%
ax=sns.lineplot(data=df,x=df['week'],y=df['revenue'],hue = 'sales_method' )
ax.set_title('average of total revenue over weeks sales for each method ')
plt.show()

# %% [markdown]
# # one variable plot shows the percentage of each sales method based on use

# %%
plt.pie(x=y,labels=x, shadow=True,rotatelabels=True,autopct='%1.2f%%',startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f9f4596adf0>,
# ...
#  [Text(-0.5442105895915244, 0.955947087540124, 'Call'),
#   Text(-0.544194344858978, -0.9559563353121877, 'Email'),
#   Text(0.94587497558149, 0.5615340867380322, 'Email + Call')],
#  [Text(-0.2968421397771951, 0.5214256841127949, '16.47%'),
#   Text(-0.296833279013988, -0.5214307283521024, '50.58%'),
#   Text(0.5159318048626309, 0.3062913200389266, '32.95%')])

# %% [markdown]
#  # spread of average revenue over week sales lookslike
#     #What does the spread of the revenue look like overall? And for each method?

# %%
sns.lineplot(data=df,x=df['week'],y=df['revenue'],ci=None)
# Out:
# <AxesSubplot: xlabel='week', ylabel='revenue'>

# %%
df.groupby(['week'])['revenue'].sum()
# Out:
# week
# 1    295146.48
# 2    215400.84
# 3    200078.75
# 4    257272.51
# 5    282675.43
# 6    183112.17
# Name: revenue, dtype: float64

# %% [markdown]
# # this matrix shows how many nb_sold and total revenue for each week
# #Was there any difference in revenue over time for each of the methods?
# # yes for sure we can see that the first week has the higest products sold and total revenue
# #but in terms of average the sixh week has the highest average and lowest number of product sold

# %%
df.groupby(['week'])['nb_sold','revenue'].agg({'nb_sold':'count','revenue':'sum'})
# Out:
#       nb_sold    revenue
# week
# 1        3721  295146.48
# 2        2491  215400.84
# 3        2411  200078.75
# 4        2575  257272.51
# 5        2574  282675.43
# 6        1228  183112.17

# %% [markdown]
#  # spread of average revenue over week sales lookslike and for each method   three variables plot

# %%
sns.scatterplot(data=df,x='week',y='revenue',hue='sales_method')
# Out:
# <AxesSubplot: xlabel='week', ylabel='revenue'>

# %% [markdown]
# # spread of revenue this hist shows the distrbution of revenue
# #What does the spread of the revenue look like overall? And for each method?

# %%
plt.hist(df['revenue'],bins=20)
# Out:
# (array([1.661e+03, 2.293e+03, 5.810e+02, 4.270e+02, 6.540e+02, 2.535e+03,
#         2.436e+03, 1.471e+03, 2.010e+02, 2.660e+02, 4.000e+01, 4.270e+02,
#         6.200e+01, 1.900e+01, 1.049e+03, 3.880e+02, 2.000e+00, 0.000e+00,
#         2.800e+02, 2.080e+02]),
#  array([ 32.54 ,  42.829,  53.118,  63.407,  73.696,  83.985,  94.274,
#         104.563, 114.852, 125.141, 135.43 , 145.719, 156.008, 166.297,
#         176.586, 186.875, 197.164, 207.453, 217.742, 228.031, 238.32 ]),
#  <BarContainer object of 20 artists>)

# %%
df['revenue'].max()
# Out:
# 238.32

# %%
s=df.groupby(['week'])['revenue'].sum().index

# %%
l=df.groupby(['week'])['revenue'].sum().values

# %% [markdown]
# #Was there any difference in revenue over time for each of the methods?
# # yes for sure we can see that the first week has the higest products sold and total revenue
# #but in terms of average the sixh week has the highest average and lowest number of product sold

# %%
plt.bar(s,l)
plt.title('distrbution of revenue over week sales')
plt.xlabel('weeks sales')
plt.ylabel('revenue')
plt.show()

# %%
df.groupby(['week'])['revenue'].sum()
# Out:
# week
# 1    295146.48
# 2    215400.84
# 3    200078.75
# 4    257272.51
# 5    282675.43
# 6    183112.17
# Name: revenue, dtype: float64

# %% [markdown]
# #Was there any difference in revenue over time for each of the methods?
#
# yes for sure we can see that the first week has the higest products sold and total revenue
# #but in terms of average the sixth week has the highest average and lowest number of product sold

# %%
df.groupby(['week'])['revenue'].mean()
# Out:
# week
# 1     79.319129
# 2     86.471634
# 3     82.985794
# 4     99.911654
# 5    109.819514
# 6    149.114145
# Name: revenue, dtype: float64

# %%
df
# Out:
#        week  sales_method  ...          state  Customer_segments
# 0         2         Email  ...        Arizona       New_customer
# 1         6  Email + Call  ...         Kansas       New_customer
# 2         5          Call  ...      Wisconsin       New_customer
# 3         4         Email  ...        Indiana       New_customer
# 4         3         Email  ...       Illinois       New_customer
# ...     ...           ...  ...            ...                ...
# 14995     4          Call  ...   Pennsylvania       New_customer
# 14996     5          Call  ...         Kansas       New_customer
# 14997     1          Call  ...  West Virginia       New_customer
# 14998     6          Call  ...     New Jersey       New_customer
# 14999     5  Email + Call  ...       Illinois       New_customer
#
# [15000 rows x 9 columns]
